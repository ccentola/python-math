# %% [markdown]
# # Natural Exponent and Logorithim

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-3,3,99)


plt.plot(x,np.exp(x))
plt.xlabel('x')
plt.ylabel('$y=e^x$')
plt.show()

plt.plot(x,np.log(x))
plt.xlabel('x')
plt.ylabel('log(x)')

plt.show()
# Out:
# /home/ccentola/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':
# /home/ccentola/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in log
#   if __name__ == '__main__':
