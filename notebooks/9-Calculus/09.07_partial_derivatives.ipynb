# %% [markdown]
# # Partial Derivatives

# %%
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display,Math

# %%
from sympy.abc import x,y

f = x**2 + x*y**2

display(Math('\\frac{\\partial f}{\\partial x} = %s' %sym.latex(sym.diff(f,x))))
display(Math('\\frac{\\partial f}{\\partial x} = %s' %sym.latex(sym.diff(f,y))))
# Out:
# $\displaystyle \frac{\partial f}{\partial x} = 2 x + y^{2}$
# $\displaystyle \frac{\partial f}{\partial x} = 2 x y$

# %%
p = sym.plotting.plot3d(f,
                        (x,-3,3),
                        (y,-3,3),
                        title='$f(x,y)=%s$' %sym.latex(f)
                    )
p = sym.plotting.plot3d(sym.diff(f,x),
                        (x,-3,3),
                        (y,-3,3),
                        title='$f(x,y)=%s$' %sym.latex(sym.diff(f,x))
                    )

p = sym.plotting.plot3d(sym.diff(f,y),
                        (x,-3,3),
                        (y,-3,3),
                        title='$f(x,y)=%s$' %sym.latex(sym.diff(f,y))
                    )
