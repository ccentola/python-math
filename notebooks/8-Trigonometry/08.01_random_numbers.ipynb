# %% [markdown]
# # Random Numbers

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nums = np.random.rand()
nums
# Out:
# 0.49198615682445834

# %%
nums = np.random.rand(1000)

plt.plot(nums,'s')
plt.show()

plt.hist(nums)
plt.show()

# %%
nums = np.random.rand(1000)

nums = nums + 3

plt.plot(nums,'s')
plt.show()

plt.hist(nums)
plt.show()

# %%
nums = np.random.rand(1000)

min_val = 2
max_val = 17

nums = nums*(max_val-min_val) + min_val

plt.plot(nums,'s')
plt.show()

plt.hist(nums)
plt.show()

# %%
# normal dist
nums = np.random.randn(1000)

min_val = 2
max_val = 17

nums = nums*(max_val-min_val) + min_val

plt.plot(nums,'s')
plt.show()

plt.hist(nums)
plt.show()

# %%
m = 15
sd = 4.3

# normalize to get exact values
nums = np.random.randn(1000) * sd + m
nums = nums - np.mean(nums)
nums = nums/np.std(nums)
nums = nums * sd + m

plt.plot(nums,'s')
plt.show()

plt.hist(nums)
plt.show()

print(f'The distribution has a mean of {np.mean(nums)} and an sd of {np.std(nums)}')
# Out:
# The distribution has a mean of 15.000000000000004 and an sd of 4.3
