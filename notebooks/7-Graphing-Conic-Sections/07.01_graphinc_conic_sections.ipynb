# %% [markdown]
# # Graphing Conic Sections

# %% [markdown]
# ## Graphing Conic Sections

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 1
h = 1
p = 1/(4*a)
k = -2
n = 100
d = k-p

# x-axis
x = np.linspace(h-5,h+5,n)

y = a*(x-h)**2 + k

plt.plot(x,y,label='parabola')
plt.plot(h,k,'ro',label='vertex')
plt.plot(h,k+p,'go',label='focus')


plt.plot(x[[0,-1]],[d,d],label='directix')

plt.legend()
plt.grid()


plt.show()

# %% [markdown]
# ## Creating Contours from Meshes

# %%
x,y = np.meshgrid(range(0,10),range(0,15))

plt.subplot(121)
plt.pcolormesh(x,edgecolor='k',linewidth=0.1)

plt.subplot(122)
plt.pcolormesh(y,edgecolor='k',linewidth=0.1)

# %%
x = np.linspace(-np.pi,2*np.pi,40)
y = np.linspace(0,4*np.pi,72)

X,Y = np.meshgrid(x,y)

fxy = np.cos(X) + np.sin(Y)

plt.imshow(fxy)
plt.show()

# %%
x = np.linspace(-2,2,100)
y = np.linspace(-2,2,100)
s = 2

X,Y = np.meshgrid(x,y)

fxy = np.exp( -(X**2+Y**2) / s )

plt.imshow(fxy)

plt.show()

# %% [markdown]
# ## Graphing Circles

# %%
h = 2
k = -3
r = 3

axlim = r + np.max((abs(h),abs(k)))

x = np.linspace(-axlim,axlim,100)
y = np.linspace(-axlim,axlim,100)

X,Y = np.meshgrid(x,y)

f = (X-h)**2 + (Y-k)**2 - r**2

plt.plot([-axlim,axlim],[0,0],'k--')
plt.plot([0,0],[-axlim,axlim],'k--')
plt.plot(h,k,'go')

plt.gca().set_aspect('equal')

plt.contour(X,Y,f,0)

# %%
h = [-1.5,1.5]

x = np.linspace(-5,5,100)

X,Y = np.meshgrid(x,x)

for i in np.linspace(.5,3,15):
    for j in h:
        f = (X-j)**2 + Y**2 - i**2
        plt.contour(X,Y,f,0,colors=[i/3,i/3,i/3])


        
        
plt.gca().set_aspect('equal')
plt.axis('off')
plt.plot(h,[0,0],'k',linewidth=3)
        
plt.show()

# %% [markdown]
# ## Graphing Ellipses

# %%
h = 1
k = 2
a = 2
b = 3

axlim = np.max((a,b)) + np.max((abs(h),abs(k)))
x = np.linspace(-axlim,axlim,100)

X,Y = np.meshgrid(x,x)

f = (X-h)**2 / a**2 + (Y-k)**2 / b**2 - 1

plt.contour(X,Y,f,0)
plt.gca().set_aspect('equal')

plt.show()

# %%
n = 16
h = 0
k = np.linspace(-4,4,n)
a = abs(k)
b = 4

x = np.linspace(-8,8,100)
X,Y = np.meshgrid(x,x)

for i in range(0,n):
    f = (X-h)**2 / a[i]**2 + (Y-k[i])**2 / b**2 - 1
    plt.contour(X,Y,f,0,colors=[i/n,0,i/n])

plt.axis('off')
plt.gca().set_aspect('equal')

plt.show()

# %% [markdown]
# ## Graphing Hyperbolas

# %%
h = 1
k = 2
a = 1
b = 0.5

axlim = 2 * np.max((a,b)) + np.max((abs(h),abs(k)))
x = np.linspace(-axlim,axlim,100)

X,Y = np.meshgrid(x,x)

f = (X-h)**2 / a**2 - (Y-k)**2 / b**2 - 1

plt.contour(X,Y,f,0)
plt.gca().set_aspect('equal')

plt.plot([-axlim,axlim],[0,0],'k--')
plt.plot([0,0],[-axlim,axlim],'k--')
plt.plot(h,k,'go')

plt.show()

# %%
n = 16
ab = np.linspace(1,5,n)

axlim = 8
x = np.linspace(-axlim,axlim,100)

X,Y = np.meshgrid(x,x)

for i in range(0,n):
    
    # horizontal
    f1 = X**2 / ab[i]**2 - Y**2 / ab[i]**2 - 1
    plt.contour(X,Y,f1,0,colors=[i/n,0,i/n])
    
    # vertical
    f2 =  -(Y**2 / ab[i]**2 - 1) + X**2 / ab[i]**2
    plt.contour(X,Y,f2,0,colors=[0,i/n,i/n])
    
    
plt.gca().set_aspect('equal')
plt.axis('off')

plt.show()
