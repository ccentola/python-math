# %% [markdown]
# # Graphing using Sympy

# %%
import sympy as sym
from sympy.abc import x

# %%
y = x**2

p = sym.plotting.plot(y)
print(p)
# Out:
# Plot object containing:
# [0]: cartesian line: x**2 for x over (-10.0, 10.0)

# %%
x, a = sym.symbols('x,a')

expr = a/x

p = sym.plotting.plot(expr.subs(a,1),(x,-5,5),show=False)

p.ylim = [-5,5]
p.show()
